# %%
import pandas as pd
from konlpy.tag import Mecab
from gensim.models.doc2vec import TaggedDocument
from tqdm import tqdm

# %% [markdown]
# <h2>1) 공시 사업 보고서 로드 및 전처리</h2>

# %%
# https://drive.google.com/uc?id=1XS0UlE8gNNTRjnL6e64sMacOhtVERIqL 에서 다운로드
# 데이터 불러오기
df = pd.read_csv('dart.csv',  sep=',')
df = df.dropna()
df
# Out:
#         code  market    name  \
# 0     000020   KOSPI    동화약품
# 1     000040   KOSPI   KR모터스
# 2     000050   KOSPI      경방
# 3     000060   KOSPI   메리츠화재
# 4     000070   KOSPI   삼양홀딩스
# ...      ...     ...     ...
# 2582  950130  KOSDAQ  엑세스바이오
# 2583  950140  KOSDAQ   잉글우드랩
# 2584  950160  KOSDAQ  코오롱티슈진
# 2585  950170  KOSDAQ     JTC
# 2586  950180  KOSDAQ     SNK
#
#                                                business
# 0     II. 사업의 내용\n1. 사업의 개요\n가. 일반적인 사항\n기업회계기준서 제11...
# 1     II. 사업의 내용\n1. 사업의 개요\n가. 업계의 현황\n수출주력시장인 유럽 불...
# 2     II. 사업의 내용\n1. 사업의 개요\n(1) 산업의 특성\n[섬유사업부문]\n면...
# 3     II. 사업의 내용\n1. 사업의 개요\n가. 산업의 특성, 성장성, 경기변동의 특...
# 4     II. 사업의 내용\n1. 사업의 개요\n가. 업계의 현황\n지주회사(持株會社, H...
# ...                                                 ...
# 2582  II. 사업의 내용\n1. 사업의 개\n요\n당사는 체외진단 기술을 토대로 말라리아...
# 2583  II. 사업의 내용\n1. 사업의 개요\n가. 화장품 ODM산업 개요\nODM은 O...
# 2584  II. 사업의 내용\n당사는 1999년 6월 9일 세포 유전자 기술 Platform...
# 2585  II. 사업의 내용\n1. 사업의 개요\n가. 업계의 현황\n(1) 산업의 특성\n...
# 2586  II. 사업의 내용\n1. 사업의 개요\n당사는 연결실체 기준으로 모바일, 콘솔, ...
#
# [2295 rows x 4 columns]

# %%
# tags에 '제목을' 토큰화
# words에 '본문을' 토큰화
mecab = Mecab()

tagged_corpus_list = []

for index, row in tqdm(df.iterrows(), total=len(df)):
  text = row['business']
  tag = row['name']
  tagged_corpus_list.append(TaggedDocument(tags=[tag], words=mecab.morphs(text)))

print('문서의 수 :', len(tagged_corpus_list))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File c:\Users\winte\AppData\Local\Programs\Python\Python311\Lib\site-packages\MeCab\__init__.py:137, in Tagger.__init__(self, rawargs)
#     136 try:
# --> 137     super(Tagger, self).__init__(args)
#     138 except RuntimeError as ee:
#
# RuntimeError:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File c:\Users\winte\AppData\Local\Programs\Python\Python311\Lib\site-packages\konlpy\tag\_mecab.py:77, in Mecab.__init__(self, dicpath)
#      76 try:
# ---> 77     self.tagger = Tagger('-d %s' % dicpath)
#      78     self.tagset = utils.read_json('%s/data/tagset/mecab.json' % utils.installpath)
#
# File c:\Users\winte\AppData\Local\Programs\Python\Python311\Lib\site-packages\MeCab\__init__.py:139, in Tagger.__init__(self, rawargs)
#     138 except RuntimeError as ee:
# --> 139     raise RuntimeError(error_info(rawargs)) from ee
#
# RuntimeError:
# ----------------------------------------------------------
#
# Failed initializing MeCab. Please see the README for possible solutions:
#
#     https://github.com/SamuraiT/mecab-python3#common-issues
#
# If you are still having trouble, please file an issue here, and include the
# ERROR DETAILS below:
#
#     https://github.com/SamuraiT/mecab-python3/issues
#
# issueを英語で書く必要はありません。
#
# ------------------- ERROR DETAILS ------------------------
# arguments: -d /usr/local/lib/mecab/dic/mecab-ko-dic
# default dictionary path: None
# [ifs] no such file or directory: c:\mecab\mecabrc
# ----------------------------------------------------------
#
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # tags에 '제목을' 토큰화
#       2 # words에 '본문을' 토큰화
# ----> 3 mecab = Mecab()
#       5 tagged_corpus_list = []
#       7 for index, row in tqdm(df.iterrows(), total=len(df)):
#
# File c:\Users\winte\AppData\Local\Programs\Python\Python311\Lib\site-packages\konlpy\tag\_mecab.py:80, in Mecab.__init__(self, dicpath)
#      78     self.tagset = utils.read_json('%s/data/tagset/mecab.json' % utils.installpath)
#      79 except RuntimeError:
# ---> 80     raise Exception('The MeCab dictionary does not exist at "%s". Is the dictionary correctly installed?\nYou can also try entering the dictionary path when initializing the Mecab class: "Mecab(\'/some/dic/path\')"' % dicpath)
#      81 except NameError:
#      82     raise Exception('Install MeCab in order to use it: http://konlpy.org/en/latest/install/')
#
# Exception: The MeCab dictionary does not exist at "/usr/local/lib/mecab/dic/mecab-ko-dic". Is the dictionary correctly installed?
# You can also try entering the dictionary path when initializing the Mecab class: "Mecab('/some/dic/path')"
